# %%
import numpy as np

# %%
lst_marks = [45,32,56,75,89,54,32,90,87,67,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum = np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
print('Minimum value :', minimum)
print('Lower quantile Q1 : ', Q1)
print('Median value :', median)
print('Upper quantile Q3 :', Q3)
print('Maximum value :', maximum)
# Out:
# Minimum value : 32.0
# Lower quantile Q1 :  51.75
# Median value : 67.0
# Upper quantile Q3 : 87.5
# Maximum value : 99.0

# %%
IQR  = Q3-Q1
print(IQR)
# Out:
# 35.75

# %%
lower_fence = Q1-1.5*(IQR)
higher_fence = Q3+1.5*(IQR)

# %%
print(lower_fence,higher_fence)
# Out:
# 3.5 139.5

# %%
lst_marks = [45,32,56,75,89,54,32,90,87,67,54,45,98,99,67,74]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %% [markdown]
# #### Adding outlier data on upper and lower side

# %%
lst_marks = [45,32,56,75,89,54,32,90,87,67,54,45,98,99,67,74,1000,1200,1300]
